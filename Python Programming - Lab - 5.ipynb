# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 5</b></center>
# <center><b><h3>Roll No.: 458</b></center>
# <center><b><h3>Name: Shyam S. Sherasiya</b></center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
a=input("Enter String")
UP=0
LW=0
Dgt=0
Spe=0
for i in a:
    if i.islower():
        LW+=1
    elif i.isupper():
        UP+=1
    elif i.isdigit():
        Dgt+=1
    else:
        Spe+=1
print(f"Uppercase: {UP}, Lowercase: {LW}, Digits: {Dgt}, Special: {Spe}")
# Out:
# Enter String Python3@Lab
# Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
a=input("Enter String")

b=a.split(" ")
c=[]

for i in b:
    c.append(i[::-1])
x = " ".join(c)
print(x)
# Out:
# Enter String Python is Easy
# nohtyP si ysaE

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
a=input("Enter String")

if a.isupper():
    print(f"{a} -> Upper Case")
elif a.islower():
    print(f"{a} -> Lower Case")
elif a.istitle():
    print(f"{a} -> Title Case")
# Out:
# Enter String Python
# Python -> Title Case

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
a=input("Enter String")
b=input("Enter character to find")

F=a.find(f"{b}")
L=a.rfind(f"{b}")

print(f"First:{F} Last:{L}")
# Out:
# Enter String programming
# Enter character to find g
# First:3 Last:10

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
a=input("Enter String")
b=input("Enter word to find")
a=a.lower()
b=b.lower()
Fr=a.count(f"{b}")

print(f"{b} : {Fr}")
# Out:
# Enter String Python is easy and Python is powerful
# Enter word to find python
# python : 2

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
a=input("Enter String")
b=a.split()
c=" ".join(b)
print(c)
# Out:
# Enter String  Python   is   fun
# Python is fun

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
a=input("Enter String")
b=input("Enter prefix")
c=input("Enter suffix")

a=a.removeprefix(f"{b}")
a=a.removesuffix(f"{c}")

print(a)
# Out:
# Enter String unhappy.txt
# Enter prefix un
# Enter suffix .txt
# happy

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
a=input("Enter String")
b="aeiou"
c = ""
for i in a:
    if i not in b:
        c+=i
    else:
        c+="*"
print(c)
# Out:
# Enter String Programming
# Pr*gr*mm*ng

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
a=input("Enter String")
cnt=1
b =""
for i in range(1,len(a)):
    if(a[i]==a[i-1]):
        cnt+=1
    else:
        b = b + a[i - 1] + str(cnt)
        cnt=1
b = b + a[-1] + str(cnt)
print(b)
# Out:
# Enter String aaabbcccc
# a3b2c4

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
a=input("Enter String")
b=""

for i in range(len(a)):
    if a[i].islower():
        b+=a[i].upper()
    else:
        b+=a[i].lower()
print(b)
# Out:
# Enter String PyThOn
# pYtHoN

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
a=input("Enter String")

if(a.isalnum() and not a[0].isdigit() and len(a)>=6):
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter String Us@12
# Invalid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
a=input("Enter String")

if(a[::-1].lower()==a.lower()):
    print("Palidrome")
else:
    print("Not Palidrome")
# Out:
# Enter String Madam
# Palidrome

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
a=input("Enter String")

wordlist=a.split()

longest=wordlist[0]

for i in wordlist:
    if len(i)> len(longest):
        longest=i
print(longest)
# Out:
# Enter String Python programming is interesting
# programming

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
a=input("Enter String")

print(a.lower())
print(a.upper())
print(a.title())
print(a.capitalize())
# Out:
# Enter String python programming
# python programming
# PYTHON PROGRAMMING
# Python Programming
# Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
a=input("Enter String :")
b=input("Enter delimiter :")

c=a.split(b)

print(c)
# Out:
# Enter String : 10|20|30
# Enter delimiter : |
# ['10', '20', '30']
