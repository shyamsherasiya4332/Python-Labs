# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World..!!")
# Out:
# Hello World..!!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
a = input("Enter your name")
print(f'Hello {a} ,Welcome to python Lab.')
# Out:
# Enter your name Priya
# Hello Priya ,Welcome to python Lab.

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
a,b,c=input("Enter Number").split()
a=int(a)
b=int(b)
c=int(c)

sum=a+b+c

print(f'Numbers: {a} {b} {c}\nSum:{sum} \nAverage:{sum/3}')
# Out:
# Enter Number 10 20 30
# Numbers: 10 20 30
# Sum:60
# Average:20.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
fn,age,per=input("Enter Your Details").split(',')
age=int(age)
per=float(per)

print(f"""Name: {fn} Type: {type(fn)} \nAge: {age} Type: {type(age)} \nPercentage: {per} Type: {type(per)}""")
# Out:
# Enter Your Details Riya,18,92.5
# Name: Riya Type: <class 'str'>
# Age: 18 Type: <class 'int'>
# Percentage: 92.5 Type: <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python","Programming","Basic",sep=" | ",end="###")
# Out:
# Python | Programming | Basic###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
a=input("Enter Hello")

print(f"""Value: {a} \nType: {type(a)} \nID: {id(a)}""")
# Out:
# Enter Hello hello
# Value: hello
# Type: <class 'str'>
# ID: 1889339790112

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
a=5
print(f"Original ID od a: {id(a)}")
a=7
print(f"New ID od a: {id(a)}")
# Out:
# Original ID od a: 140708617958440
# New ID od a: 140708617958504

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print(f"""Welcome to Python \nThis is the second lab \nEnjoy coding!""")
# Out:
# Welcome to Python
# This is the second lab
# Enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'Sr No':^9}{'Name':^10}{'Subject':^9}{'Grade':^8}{'Percentage':^10}")
print(f"{'1':>7}{'Nisha Patel':^14}{'Math':<7}{'A':^7}{'92':>11}")
print(f"{'2':>7}{'Aarav Modi':^13}{'Science':<5}{'B+':^10}{'85':>9}")
print(f"{'3':>7}{'Jiya Shah':^13}{'English':<5}{'A+':^10}{'96':>9}")
# Out:
#   Sr No     Name    Subject  Grade  Percentage
#       1 Nisha Patel  Math      A            92
#       2 Aarav Modi  Science    B+           85
#       3  Jiya Shah  English    A+           96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
a=float(input("Enter number"))

print(f"""2 decimals: {a: .2f}
3 decimals: {a: .3f}
Width 10: {a: 10.2f}""")
# Out:
# Enter number 25.2567
# 2 decimals:  25.26
# 3 decimals:  25.257
# Width 10:      25.26

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a,b=input("Enter 2 number").split()
a=int(a)
b=int(b)

print(f"""Sum = {a+b}
Difference = {a-b}
Product = {a*b}""")
# Out:
# Enter 2 number 12 8
# Sum = 20
# Difference = 4
# Product = 96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
a,b,c=input("Enter date").split()
print(a,b,c,sep='/')
print(c,b,a,sep='-')
# Out:
# Enter date 01 12 2025
# 01/12/2025
# 2025-12-01

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
import math
r=int(input("Enter radius"))

area=(math.pi)*r*r
perimeter=2*(math.pi)*r

print(f"Area = {area} \nPerimeter = {perimeter}")
# Out:
# Enter radius 10
# Area = 314.1592653589793
# Perimeter = 62.83185307179586

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
f=float(input("Enter Fahrenheit"))

cels=(f-32)*5/9

print(f"{f} Fahrenheit ={cels} Celsius")
# Out:
# Enter Fahrenheit 68
# 68.0 Fahrenheit =20.0 Celsius

# %%
c=float(input("Enter Degree"))

fahr=(c*9/5)+32

print(f"{c} Celsius ={fahr} Fahrenheit")
# Out:
# Enter Degree 20
# 20.0 Celsius =68.0 Fahrenheit

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
k=int(input("Enter Distance in Kilometer"))

m=float(k*1000)

feet=float(k*3280.84)

inches=float(k*39370.1)

centimeter=float(k*100000)

print((f"{k} Kilometer ={m} Meter \n{k} Kilometer ={feet} Feet \n{k} Kilometer ={inches} Inches \n{k} Kilometer ={centimeter} Centimeter"))
# Out:
# Enter Distance in Kilometer 5
# 5 Kilometer =5000.0 Meter
# 5 Kilometer =16404.2 Feet
# 5 Kilometer =196850.5 Inches
# 5 Kilometer =500000.0 Centimeter
