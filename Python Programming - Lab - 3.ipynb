# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
a=int(input("Enter positive or nagative number"))

if(a>0):
    print(f"{a} is positive number")
else:
    print(f"{a} is negative number")
# Out:
# Enter positive or nagative number -2
# -2 is negative number

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
a=int(input("Enter number"))

if(a%2==0):
    print(f"{a} is even number")
else:
    print(f"{a} is odd number")
# Out:
# Enter number 3
# 3 is odd number

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
#Simple if

a=int(input("Enter first number"))
b=int(input("Enter second number"))

if(a>b):
    print(f"{a} is larger number")
else:
    print(f"{b} is larger number")

#ternary operator

a=int(input("Enter first number"))
b=int(input("Enter second number"))

print(f"{a} is larger number") if a>b else print(f"{b} is larger number")
# Out:
# Enter first number 4
# Enter second number 5
# 5 is larger number

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
#nested if

a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))

if(a>b):
    if(a>c):
        print(f"{a} is larger number")
    else:
        print(f"{c} is larger number")
else:
    if(b>c):
        print(f"{b} is larger number")
    else:
        print(f"{c} is larger number")

#ternary operator

a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))

print(f"{a} is larger number") if (a>b and a>c) else(print(f"{b} is larger number") if b>c else print(f"{c} is larger number"))
# Out:
# Enter first number 5
# Enter second number 4
# Enter third number 3
# 5 is larger number

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
year=int(input("Enter Year"))

if((year%4==0 and year%100!=0) or year%400==0):
    print(f"{year} is leap year")
else:
    print(f"{year} is not leap year")
# Out:
# Enter Year 2023
# 2023 is not leap year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
choice=int(input("Enter day 1-7 : "))

match choice:
    case 1:
        print("Moday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case 7:
        print("Sunday")
# Out:
# Enter day 1-7 :  5
# Friday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
a=int(input("Enter First Number"))
b=int(input("Enter Second Number"))

choice = int(input(f"""Enter 1 for +
Enter 2 for -
Enter 3 for *
Enter 4 for / \n"""))

match choice:
    case 1:
        print(f"Summation = {a+b}")
    case 2:
        print(f"Substraction = {a-b}")
    case 3:
        print(f"Multiplication = {a*b}")
    case 4:
        print(f"Division = {a/b}")
# Out:
# Enter First Number 5
# Enter Second Number 7
# Enter 1 for +
# Enter 2 for -
# Enter 3 for *
# Enter 4 for /
#  3
# Multiplication = 35

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# #### Fail below 35
# #### Pass Class between 35 to 45
# #### Second Class
# #### between 45 to 60
# #### First Class between 60 to 70
# #### Distinction if more than 70

# %%
a=int(input("Enter Your Marks"))

if(a>70):
    print("Distinct")
elif(a>60):
    print("First Class")
elif(a>45):
    print("Second Class")
elif(a>35):
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Your Marks 90
# Distinct

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))

if((a>b and a<c) or (a<b and a>c)):
    print(f"{a} is second largest number")
elif((b>a and b<c) or (b<a and b>c)):
    print(f"{b} is second largest number")
else:
    print(f"{c} is second largest number")
# Out:
# Enter first number 3
# Enter second number 4
# Enter third number 5
# 4 is second largest number

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
units=float(input("Enter your units"))

if(units<=50):
    b=2.60*units
elif(units<=100):
    b=(3.25*(units-50))+(50*2.6)
elif(units<=200):
    b=(5.26*(units-100))+(50*3.25)+(50*2.6)
else:
    b=(8.45*(units-200))+(100*5.26)+(50*3.25)+(50*2.6)
print(f"Total Bill = {b}")
# Out:
# Enter your units 300
# Total Bill = 1663.5
